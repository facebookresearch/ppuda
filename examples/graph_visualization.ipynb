# %%
# Copyright (c) Facebook, Inc. and its affiliates.
# All rights reserved.
#
# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.

import torch
import torchvision

from ppuda.deepnets1m.graph import Graph
from ppuda.deepnets1m.net import Network
from ppuda.deepnets1m.genotypes import ViT, DARTS

# %%
print('ResNet-50')
Graph(torchvision.models.resnet50()).visualize(node_size=100)

print('Visual Transformer')
model = Network(C=128, num_classes=1000, genotype=ViT, n_cells=12, preproc=False, C_mult=1)
Graph(model).visualize(node_size=100)

print('DARTS')
model = Network(C=48, num_classes=1000, genotype=DARTS, n_cells=14, preproc=True, C_mult=2)
Graph(model).visualize(node_size=50)

print('VGG16-BN')
Graph(torchvision.models.vgg16_bn()).visualize(node_size=50)

print('MobileNet')
Graph(torchvision.models.mobilenet_v2()).visualize(node_size=50)

print('DenseNet-201')
Graph(torchvision.models.densenet201()).visualize(node_size=30)

print('legend')
Graph(torch.nn.Conv2d(3, 16, 3)).visualize(node_size=200, figsize=(20,3), with_labels=True, vis_legend=True, label_offset=0.0005)
# Out:
# ResNet-50
# Visual Transformer
# /home/maria/gnn/gnnsolver-review-packaging/ppuda_env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1061: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)
# DARTS
# VGG16-BN
# MobileNet
# DenseNet-201
# legend
# /home/maria/gnn/gnnsolver-review-packaging/ppuda_env/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1061: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x = np.asanyarray(x)
